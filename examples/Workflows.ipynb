# %% [markdown]
# ## Import Package

# %%
from cumulus_api import CumulusApi

# %% [markdown]
# ## Initialize Cumulus API Class

# %%
cml = CumulusApi()

# %% [markdown]
# ## Get the latest API version from Cumulus

# %%
cml.list_workflows(limit=1)
# Out:
# [{'arn': 'arn:aws:states:us-west-2:xxxxxxxxxxxx:stateMachine:sharedsbx-DeleteGranules',
#   'definition': {'Comment': 'Ageoff granules from S3 and Cumulus',
#    'StartAt': 'AgeOff_Granules',
#    'States': {'AgeOff_Granules': {'Catch': [{'ErrorEquals': ['States.ALL'],
#        'Next': 'WorkflowFailed',
#        'ResultPath': '$.exception'}],
#      'Next': 'WorkflowSucceeded',
#      'Parameters': {'cma': {'event.$': '$',
#        'task_config': {'buckets': '{$.meta.buckets}',
#         'collection': '{$.meta.collection}',
#         'cumulus_message': {'input': '{$.meta.collection.meta}',
#          'outputs': [{'destination': '{$.payload}', 'source': '{$}'}]}}}},
#      'Resource': 'arn:aws:lambda:us-west-2:xxxxxxxxxxxx:function:sharedsbx-ageoff-lambda',
#      'Retry': [{'BackoffRate': 2,
#        'ErrorEquals': ['Lambda.ServiceException',
#         'Lambda.AWSLambdaException',
#         'Lambda.SdkClientException'],
#        'IntervalSeconds': 2,
#        'MaxAttempts': 6}],
#      'Type': 'Task'},
#     'WorkflowFailed': {'Cause': 'Workflow failed', 'Type': 'Fail'},
#     'WorkflowSucceeded': {'Type': 'Succeed'}}},
#   'name': 'DeleteGranules'},
#  {'arn': 'arn:aws:states:us-west-2:xxxxxxxxxxxx:stateMachine:sharedsbx-DiscoverGranules',
#   'definition': {'Comment': 'Discovers new Granules from a given provider',
#    'StartAt': 'DynamicChangeEvent',
#    'States': {'ActivityOrLambda': {'Choices': [{'And': [{'IsPresent': True,
#          'Variable': '$.meta.collection.meta.large_dataset'},
#         {'StringEquals': 'true',
#          'Variable': '$.meta.collection.meta.large_dataset'}],
#        'Next': 'DiscoverGranulesActivity'}],
#      'Default': 'DiscoverGranulesStandardOrCustom',
#      'Type': 'Choice'},
#     'DiscoverGranulesActivity': {'Catch': [{'ErrorEquals': ['States.ALL'],
#        'Next': 'WorkflowFailed',
#        'ResultPath': '$.exception'}],
#      'Next': 'QueueGranulesActivity',
#      'Parameters': {'cma': {'ReplaceConfig': {'FullMessage': True},
#        'event.$': '$',
#        'task_config': {'buckets': '{$.meta.buckets}',
#         'collection': '{$.meta.collection}',
#         'duplicateGranuleHandling': '{$.meta.collection.duplicateHandling}',
#         'provider': '{$.meta.provider}',
#         'provider_path': '{$.meta.collection.meta.provider_path}',
#         'stack': '{$.meta.stack}'}}},
#      'Resource': 'arn:aws:states:us-west-2:xxxxxxxxxxxx:activity:sharedsbx-DiscoverGranules',
#      'Retry': [{'BackoffRate': 2,
#        'ErrorEquals': ['Lambda.ServiceException',
#         'Lambda.AWSLambdaException',
#         'Lambda.SdkClientException'],
#        'IntervalSeconds': 2,
#        'MaxAttempts': 6}],
#      'Type': 'Task'},
#     'DiscoverGranulesLambda': {'Catch': [{'ErrorEquals': ['States.ALL'],
#        'Next': 'WorkflowFailed',
#        'ResultPath': '$.exception'}],
#      'Next': 'QueueGranulesLambda',
#      'Parameters': {'cma': {'ReplaceConfig': {'FullMessage': True},
#        'event.$': '$',
#        'task_config': {'buckets': '{$.meta.buckets}',
#         'collection': '{$.meta.collection}',
#         'duplicateGranuleHandling': '{$.meta.collection.duplicateHandling}',
#         'provider': '{$.meta.provider}',
#         'provider_path': '{$.meta.collection.meta.provider_path}',
#         'stack': '{$.meta.stack}'}}},
#      'Resource': 'arn:aws:lambda:us-west-2:xxxxxxxxxxxx:function:sharedsbx-DiscoverGranules',
#      'Retry': [{'BackoffRate': 2,
#        'ErrorEquals': ['Lambda.ServiceException',
#         'Lambda.AWSLambdaException',
#         'Lambda.SdkClientException'],
#        'IntervalSeconds': 2,
#        'MaxAttempts': 6}],
#      'Type': 'Task'},
#     'DiscoverGranulesRecursive': {'Catch': [{'ErrorEquals': ['States.ALL'],
#        'Next': 'WorkflowFailed',
#        'ResultPath': '$.exception'}],
#      'Next': 'QueueGranulesActivity',
#      'Parameters': {'cma': {'ReplaceConfig': {'FullMessage': True},
#        'event.$': '$',
#        'task_config': {'buckets': '{$.meta.buckets}',
#         'collection': '{$.meta.collection}',
#         'duplicateGranuleHandling': '{$.meta.collection.duplicateHandling}',
#         'provider': '{$.meta.provider}',
#         'provider_path': '{$.meta.collection.meta.provider_path}',
#         'stack': '{$.meta.stack}'}}},
#      'Resource': 'arn:aws:lambda:us-west-2:xxxxxxxxxxxx:function:sharedsbx-discover-granules-tf-module',
#      'Retry': [{'BackoffRate': 2,
#        'ErrorEquals': ['Lambda.ServiceException',
#         'Lambda.AWSLambdaException',
#         'Lambda.SdkClientException'],
#        'IntervalSeconds': 2,
#        'MaxAttempts': 6}],
#      'Type': 'Task'},
#     'DiscoverGranulesStandardOrCustom': {'Choices': [{'IsPresent': True,
#        'Next': 'DiscoverGranulesRecursive',
#        'Variable': '$.meta.collection.meta.discover_tf'}],
#      'Default': 'DiscoverGranulesLambda',
#      'Type': 'Choice'},
#     'DynamicChangeEvent': {'Catch': [{'ErrorEquals': ['States.ALL'],
#        'Next': 'WorkflowFailed',
#        'ResultPath': '$.exception'}],
#      'Next': 'ActivityOrLambda',
#      'Parameters': {'cma': {'ReplaceConfig': {'Path': '$.payload',
#         'TargetPath': '$.payload'},
#        'event.$': '$',
#        'task_config': {'buckets': '{$.meta.buckets}',
#         'collection': '{$.meta.collection}',
#         'cumulus_message': {'outputs': [{'destination': '{$.meta.collection}',
#            'source': '{$.config.collection}'},
#           {'destination': '{$.meta.queueUrl}',
#            'source': '{$.config.queueUrl}'}]},
#         'provider': '{$.meta.provider}',
#         'provider_path': '{$.meta.provider_path}',
#         'queueUrl': 'https://sqs.us-west-2.amazonaws.com/xxxxxxxxxxxx/sharedsbx-backgroundJobQueue',
#         'rule_collection_type': '{$.meta.rule_collection_type}',
#         'rule_provider_path': '{$.meta.rule_provider_path}',
#         'stack': '{$.meta.stack}'}}},
#      'Resource': 'arn:aws:lambda:us-west-2:xxxxxxxxxxxx:function:sharedsbx-dynamic_change_event',
#      'Retry': [{'BackoffRate': 2,
#        'ErrorEquals': ['Lambda.ServiceException',
#         'Lambda.AWSLambdaException',
#         'Lambda.SdkClientException'],
#        'IntervalSeconds': 2,
#        'MaxAttempts': 6}],
#      'Type': 'Task'},
#     'QueueGranulesActivity': {'Catch': [{'ErrorEquals': ['States.ALL'],
#        'Next': 'WorkflowFailed',
#        'ResultPath': '$.exception'}],
#      'End': True,
#      'Parameters': {'cma': {'ReplaceConfig': {'FullMessage': True},
#        'event.$': '$',
#        'task_config': {'concurrency': 900,
#         'executionNamePrefix': '{$.meta.collection.name}',
#         'granuleIngestWorkflow': 'IngestGranule',
#         'internalBucket': '{$.meta.buckets.internal.name}',
#         'provider': '{$.meta.provider}',
#         'queueUrl': '{$.meta.queueUrl}',
#         'stackName': '{$.meta.stack}'}}},
#      'Resource': 'arn:aws:states:us-west-2:xxxxxxxxxxxx:activity:sharedsbx-QueueGranules',
#      'Retry': [{'BackoffRate': 2,
#        'ErrorEquals': ['Lambda.ServiceException',
#         'Lambda.AWSLambdaException',
#         'Lambda.SdkClientException'],
#        'IntervalSeconds': 2,
#        'MaxAttempts': 6}],
#      'Type': 'Task'},
#     'QueueGranulesLambda': {'Catch': [{'ErrorEquals': ['States.ALL'],
#        'Next': 'WorkflowFailed',
#        'ResultPath': '$.exception'}],
#      'End': True,
#      'Parameters': {'cma': {'ReplaceConfig': {'FullMessage': True},
#        'event.$': '$',
#        'task_config': {'executionNamePrefix': '{$.meta.collection.name}',
#         'granuleIngestWorkflow': 'IngestGranule',
#         'internalBucket': '{$.meta.buckets.internal.name}',
#         'provider': '{$.meta.provider}',
#         'queueUrl': '{$.meta.queueUrl}',
#         'stackName': '{$.meta.stack}'}}},
#      'Resource': 'arn:aws:lambda:us-west-2:xxxxxxxxxxxx:function:sharedsbx-QueueGranules',
#      'Retry': [{'BackoffRate': 2,
#        'ErrorEquals': ['Lambda.ServiceException',
#         'Lambda.AWSLambdaException',
#         'Lambda.SdkClientException'],
#        'IntervalSeconds': 2,
#        'MaxAttempts': 6}],
#      'Type': 'Task'},
#     'WorkflowFailed': {'Cause': 'Workflow failed', 'Type': 'Fail'}},
#    'TimeoutSeconds': 18000},
#   'name': 'DiscoverGranules'},
#  {'arn': 'arn:aws:states:us-west-2:xxxxxxxxxxxx:stateMachine:sharedsbx-GHRCDiscoverGranules',
#   'definition': {'Comment': 'GHRC Discovers Granules from a given provider',
#    'StartAt': 'DynamicChangeEvent',
#    'States': {'DiscoverSFTPGranules': {'Catch': [{'ErrorEquals': ['States.ALL'],
#        'Next': 'WorkflowFailed',
#        'ResultPath': '$.exception'}],
#      'Next': 'QueueGranulesLambda',
#      'Parameters': {'cma': {'event.$': '$',
#        'task_config': {'action': 'custom_discover_sftp',
#         'buckets': '{$.meta.buckets}',
#         'collection': '{$.meta.collection}',
#         'cumulus_message': {'outputs': [{'destination': '{$.payload}',
#            'source': '{$}'}]},
#         'distribution_endpoint': '{$.meta.distribution_endpoint}',
#         'fileStagingDir': '{$.meta.collection.url_path}',
#         'files_config': '{$.meta.collection.files}',
#         'granuleIdExtraction': '{$.meta.collection.granuleIdExtraction}',
#         'provider': '{$.meta.provider}'}}},
#      'Resource': 'arn:aws:states:us-west-2:xxxxxxxxxxxx:activity:sharedsbx-EcsTaskAMSUA',
#      'Retry': [{'ErrorEquals': ['States.ALL'],
#        'IntervalSeconds': 2,
#        'MaxAttempts': 3}],
#      'Type': 'Task'},
#     'DynamicChangeEvent': {'Catch': [{'ErrorEquals': ['States.ALL'],
#        'Next': 'WorkflowFailed',
#        'ResultPath': '$.exception'}],
#      'Next': 'DiscoverSFTPGranules',
#      'Parameters': {'cma': {'ReplaceConfig': {'Path': '$.payload',
#         'TargetPath': '$.payload'},
#        'event.$': '$',
#        'task_config': {'buckets': '{$.meta.buckets}',
#         'collection': '{$.meta.collection}',
#         'cumulus_message': {'outputs': [{'destination': '{$.meta.collection}',
#            'source': '{$.config.collection}'},
#           {'destination': '{$.meta.queueUrl}',
#            'source': '{$.config.queueUrl}'}]},
#         'provider': '{$.meta.provider}',
#         'provider_path': '{$.meta.provider_path}',
#         'queueUrl': 'https://sqs.us-west-2.amazonaws.com/xxxxxxxxxxxx/sharedsbx-backgroundJobQueue',
#         'stack': '{$.meta.stack}'}}},
#      'Resource': 'arn:aws:lambda:us-west-2:xxxxxxxxxxxx:function:sharedsbx-dynamic_change_event',
#      'Retry': [{'BackoffRate': 2,
#        'ErrorEquals': ['Lambda.ServiceException',
#         'Lambda.AWSLambdaException',
#         'Lambda.SdkClientException'],
#        'IntervalSeconds': 2,
#        'MaxAttempts': 6}],
#      'Type': 'Task'},
#     'QueueGranulesLambda': {'Catch': [{'ErrorEquals': ['States.ALL'],
#        'Next': 'WorkflowFailed',
#        'ResultPath': '$.exception'}],
#      'End': True,
#      'Parameters': {'cma': {'ReplaceConfig': {'FullMessage': True},
#        'event.$': '$',
#        'task_config': {'concurrency': 900,
#         'executionNamePrefix': '{$.meta.collection.name}',
#         'granuleIngestWorkflow': 'IngestGranule',
#         'internalBucket': '{$.meta.buckets.internal.name}',
#         'provider': '{$.meta.provider}',
#         'queueUrl': '{$.meta.queueUrl}',
#         'stackName': '{$.meta.stack}'}}},
#      'Resource': 'arn:aws:lambda:us-west-2:xxxxxxxxxxxx:function:sharedsbx-QueueGranules',
#      'Retry': [{'BackoffRate': 2,
#        'ErrorEquals': ['Lambda.ServiceException',
#         'Lambda.AWSLambdaException',
#         'Lambda.SdkClientException'],
#        'IntervalSeconds': 2,
#        'MaxAttempts': 6}],
#      'Type': 'Task'},
#     'WorkflowFailed': {'Cause': 'Workflow failed', 'Type': 'Fail'}},
#    'TimeoutSeconds': 18000},
#   'name': 'GHRCDiscoverGranules'},
#  {'arn': 'arn:aws:states:us-west-2:xxxxxxxxxxxx:stateMachine:sharedsbx-HelloWorldWorkflow',
#   'definition': {'Comment': 'Returns Hello World',
#    'StartAt': 'HelloWorld',
#    'States': {'HelloWorld': {'End': True,
#      'Parameters': {'cma': {'event.$': '$',
#        'task_config': {'buckets': '{$.meta.buckets}',
#         'collection': '{$.meta.collection}',
#         'provider': '{$.meta.provider}'}}},
#      'Resource': 'arn:aws:lambda:us-west-2:xxxxxxxxxxxx:function:sharedsbx-HelloWorld',
#      'Retry': [{'BackoffRate': 2,
#        'ErrorEquals': ['Lambda.ServiceException',
#         'Lambda.AWSLambdaException',
#         'Lambda.SdkClientException'],
#        'IntervalSeconds': 2,
#        'MaxAttempts': 6}],
#      'Type': 'Task'}}},
#   'name': 'HelloWorldWorkflow'},
#  {'arn': 'arn:aws:states:us-west-2:xxxxxxxxxxxx:stateMachine:sharedsbx-IngestGranule',
#   'definition': {'Comment': 'Ingest, Process and Publish Granules',
#    'StartAt': 'SyncGranule',
#    'States': {'AMSUProcessingStep': {'Catch': [{'ErrorEquals': ['States.ALL'],
#        'Next': 'WorkflowFailed',
#        'ResultPath': '$.exception'}],
#      'Next': 'MetadataExtractor',
#      'Parameters': {'cma': {'event.$': '$',
#        'task_config': {'buckets': '{$.meta.buckets}',
#         'collection': '{$.meta.collection}',
#         'cumulus_message': {'input': '{[$.payload.granules[*].files[*].filename]}',
#          'outputs': [{'destination': '{$.payload}', 'source': '{$}'}]},
#         'distribution_endpoint': '{$.meta.distribution_endpoint}',
#         'fileStagingDir': 'amsua_staging/',
#         'files_config': '{$.meta.collection.files}',
#         'granuleIdExtraction': '{$.meta.collection.granuleIdExtraction}'}}},
#      'Resource': 'arn:aws:states:us-west-2:xxxxxxxxxxxx:activity:sharedsbx-EcsTaskAMSUA',
#      'Retry': [{'ErrorEquals': ['States.ALL'],
#        'IntervalSeconds': 2,
#        'MaxAttempts': 3}],
#      'Type': 'Task'},
#     'ChooseHyraxOrDone': {'Choices': [{'And': [{'IsPresent': True,
#          'Variable': '$.meta.collection.meta.hyrax_processing'},
#         {'StringEquals': 'true',
#          'Variable': '$.meta.collection.meta.hyrax_processing'}],
#        'Next': 'HyraxProcessing'},
#       {'And': [{'IsPresent': True,
#          'Variable': '$.meta.collection.meta.hyrax_processing'},
#         {'StringEquals': 'false',
#          'Variable': '$.meta.collection.meta.hyrax_processing'}],
#        'Next': 'PostToCMR'}],
#      'Default': 'PostToCMR',
#      'Type': 'Choice'},
#     'ChooseProcess': {'Choices': [{'Next': 'MetadataExtractor',
#        'StringEquals': 'metadataextractor',
#        'Variable': '$.meta.process'},
#       {'Next': 'MSUTProcessing',
#        'StringEquals': 'msut',
#        'Variable': '$.meta.process'},
#       {'Next': 'RSSProcessing',
#        'StringEquals': 'rss',
#        'Variable': '$.meta.process'},
#       {'Next': 'AMSUProcessingStep',
#        'StringEquals': 'amsu',
#        'Variable': '$.meta.process'}],
#      'Default': 'WorkflowSucceeded',
#      'Type': 'Choice'},
#     'CopyToGlacierOrSuccess': {'Choices': [{'Next': 'EmptyStep',
#        'StringEquals': 'notorca',
#        'Variable': '$.meta.buckets.orca_default.type'}],
#      'Default': 'WorkflowSucceeded',
#      'Type': 'Choice'},
#     'EmptyStep': {'Catch': [{'ErrorEquals': ['States.ALL'],
#        'Next': 'WorkflowFailed',
#        'ResultPath': '$.exception'}],
#      'Next': 'WorkflowSucceeded',
#      'Parameters': {'cma': {'event.$': '$',
#        'task_config': {'excludeFileTypes': '{$.meta.collection.meta.excludeFileTypes}',
#         'multipart_chunksize_mb': '{$.meta.collection.meta.multipart_chunksize_mb}'}}},
#      'Resource': 'arn:aws:lambda:us-west-2:xxxxxxxxxxxx:function:sharedsbx-HelloWorld',
#      'Retry': [{'BackoffRate': 2,
#        'ErrorEquals': ['States.ALL'],
#        'IntervalSeconds': 2,
#        'MaxAttempts': 3}],
#      'Type': 'Task'},
#     'HyraxProcessing': {'Catch': [{'ErrorEquals': ['States.ALL'],
#        'Next': 'WorkflowFailed',
#        'ResultPath': '$.exception'}],
#      'Next': 'HyraxUpdate',
#      'Parameters': {'cma': {'event.$': '$',
#        'task_config': {'buckets': '{$.meta.buckets}',
#         'collection': '{$.meta.collection}',
#         'distribution_endpoint': '{$.meta.distribution_endpoint}',
#         'fileStagingDir': 'hyrax_staging/',
#         'files_config': '{$.meta.collection.files}',
#         'granuleIdExtraction': '{$.meta.collection.granuleIdExtraction}'}}},
#      'Resource': 'arn:aws:states:us-west-2:xxxxxxxxxxxx:activity:sharedsbx-dmrpp-generator',
#      'Retry': [{'ErrorEquals': ['States.ALL'],
#        'IntervalSeconds': 2,
#        'MaxAttempts': 3}],
#      'Type': 'Task'},
#     'HyraxUpdate': {'Catch': [{'ErrorEquals': ['States.ALL'],
#        'Next': 'WorkflowFailed',
#        'ResultPath': '$.exception'}],
#      'Next': 'PostToCMR',
#      'Parameters': {'cma': {'event.$': '$',
#        'task_config': {'bucket': '{$.meta.buckets.internal.name}',
#         'cmr': '{$.meta.cmr}',
#         'granuleIdExtraction': '{$.meta.collection.granuleIdExtraction}',
#         'granules': '{$.meta.granules}',
#         'launchpad': '{$.meta.launchpad}',
#         'skipMetaCheck': True,
#         'stack': '{$.meta.stack}'}}},
#      'Resource': 'arn:aws:lambda:us-west-2:xxxxxxxxxxxx:function:sharedsbx-HyraxMetadataUpdates',
#      'Retry': [{'BackoffRate': 2,
#        'ErrorEquals': ['Lambda.ServiceException',
#         'Lambda.AWSLambdaException',
#         'Lambda.SdkClientException'],
#        'IntervalSeconds': 2,
#        'MaxAttempts': 6}],
#      'Type': 'Task'},
#     'MSUTProcessing': {'Catch': [{'ErrorEquals': ['States.ALL'],
#        'Next': 'WorkflowFailed',
#        'ResultPath': '$.exception'}],
#      'Next': 'MetadataExtractor',
#      'Parameters': {'cma': {'event.$': '$',
#        'task_config': {'buckets': '{$.meta.buckets}',
#         'collection': '{$.meta.collection}',
#         'cumulus_message': {'input': '{[$.payload.granules[*].files[*].filename]}',
#          'outputs': [{'destination': '{$.payload}', 'source': '{$}'}]},
#         'distribution_endpoint': '{$.meta.distribution_endpoint}',
#         'fileStagingDir': 'msut_staging/',
#         'files_config': '{$.meta.collection.files}',
#         'granuleIdExtraction': '{$.meta.collection.granuleIdExtraction}'}}},
#      'Resource': 'arn:aws:states:us-west-2:xxxxxxxxxxxx:activity:sharedsbx-EcsTaskMSUT',
#      'Retry': [{'ErrorEquals': ['States.ALL'],
#        'IntervalSeconds': 2,
#        'MaxAttempts': 3}],
#      'Type': 'Task'},
#     'MetadataExtractor': {'Catch': [{'ErrorEquals': ['States.ALL'],
#        'Next': 'WorkflowFailed',
#        'ResultPath': '$.exception'}],
#      'Next': 'MoveGranuleStep',
#      'Parameters': {'cma': {'event.$': '$',
#        'task_config': {'bucket': '{$.meta.buckets.internal.name}',
#         'buckets': '{$.meta.buckets}',
#         'collection': '{$.meta.collection}',
#         'cumulus_message': {'input': '{[$.payload.granules[*].files[*].filename]}',
#          'outputs': [{'destination': '{$.payload}', 'source': '{$}'}]},
#         'distribution_endpoint': '{$.meta.distribution_endpoint}',
#         'fileStagingDir': 'mdx_staging/',
#         'files_config': '{$.meta.collection.files}',
#         'granuleIdExtraction': '{$.meta.collection.granuleIdExtraction}'}}},
#      'Resource': 'arn:aws:states:us-west-2:xxxxxxxxxxxx:activity:sharedsbx-EcsTaskMDX',
#      'Retry': [{'ErrorEquals': ['States.ALL'],
#        'IntervalSeconds': 2,
#        'MaxAttempts': 3}],
#      'Type': 'Task'},
#     'MoveGranuleStep': {'Catch': [{'ErrorEquals': ['States.ALL'],
#        'Next': 'WorkflowFailed',
#        'ResultPath': '$.exception'}],
#      'Next': 'UpdateMetadataLinks',
#      'Parameters': {'cma': {'event.$': '$',
#        'task_config': {'bucket': '{$.payload.system_bucket}',
#         'buckets': '{$.meta.buckets}',
#         'collection': '{$.meta.collection}',
#         'cumulus_message': {'outputs': [{'destination': '{$.payload}',
#            'source': '{$}'},
#           {'destination': '{$.meta.processed_granules}',
#            'source': '{$.granules}'}]},
#         'distribution_endpoint': '{$.meta.distribution_endpoint}',
#         'duplicateHandling': '{$.meta.collection.duplicateHandling}'}}},
#      'Resource': 'arn:aws:lambda:us-west-2:xxxxxxxxxxxx:function:sharedsbx-MoveGranules',
#      'Retry': [{'BackoffRate': 2,
#        'ErrorEquals': ['Lambda.ServiceException',
#         'Lambda.AWSLambdaException',
#         'Lambda.SdkClientException'],
#        'IntervalSeconds': 2,
#        'MaxAttempts': 6}],
#      'Type': 'Task'},
#     'PostToCMR': {'Catch': [{'ErrorEquals': ['States.ALL'],
#        'Next': 'WorkflowFailed',
#        'ResultPath': '$.exception'}],
#      'Next': 'CopyToGlacierOrSuccess',
#      'Parameters': {'cma': {'event.$': '$',
#        'task_config': {'bucket': '{$.meta.buckets.internal.name}',
#         'cmr': '{$.meta.cmr}',
#         'granuleIdExtraction': '{$.meta.collection.granuleIdExtraction}',
#         'granules': '{$.meta.granules}',
#         'launchpad': '{$.meta.launchpad}',
#         'skipMetaCheck': True,
#         'stack': '{$.meta.stack}'}}},
#      'Resource': 'arn:aws:lambda:us-west-2:xxxxxxxxxxxx:function:sharedsbx-PostToCmr',
#      'Retry': [{'BackoffRate': 2,
#        'ErrorEquals': ['Lambda.ServiceException',
#         'Lambda.AWSLambdaException',
#         'Lambda.SdkClientException'],
#        'IntervalSeconds': 2,
#        'MaxAttempts': 6}],
#      'Type': 'Task'},
#     'RSSProcessing': {'Catch': [{'ErrorEquals': ['States.ALL'],
#        'Next': 'WorkflowFailed',
#        'ResultPath': '$.exception'}],
#      'Next': 'MetadataExtractor',
#      'Parameters': {'cma': {'event.$': '$',
#        'task_config': {'buckets': '{$.meta.buckets}',
#         'collection': '{$.meta.collection}',
#         'cumulus_message': {'input': '{[$.payload.granules[*].files[*].filename]}',
#          'outputs': [{'destination': '{$.payload}', 'source': '{$}'}]},
#         'distribution_endpoint': '{$.meta.distribution_endpoint}',
#         'fileStagingDir': 'rss_staging/',
#         'files_config': '{$.meta.collection.files}',
#         'granuleIdExtraction': '{$.meta.collection.granuleIdExtraction}'}}},
#      'Resource': 'arn:aws:states:us-west-2:xxxxxxxxxxxx:activity:sharedsbx-EcsTaskRSS',
#      'Retry': [{'ErrorEquals': ['States.ALL'],
#        'IntervalSeconds': 2,
#        'MaxAttempts': 3}],
#      'Type': 'Task'},
#     'SyncGranule': {'Catch': [{'ErrorEquals': ['States.ALL'],
#        'Next': 'WorkflowFailed',
#        'ResultPath': '$.exception'}],
#      'Next': 'ChooseProcess',
#      'Parameters': {'cma': {'ReplaceConfig': {'Path': '$.payload',
#         'TargetPath': '$.payload'},
#        'event.$': '$',
#        'task_config': {'buckets': '{$.meta.buckets}',
#         'collection': '{$.meta.collection}',
#         'cumulus_message': {'input': '{$.payload}',
#          'outputs': [{'destination': '{$.meta.granules}',
#            'source': '{$.granules}'},
#           {'destination': '{$.payload}', 'source': '{$}'},
#           {'destination': '{$.meta.process}', 'source': '{$.process}'}]},
#         'downloadBucket': '{$.cumulus_meta.system_bucket}',
#         'duplicateHandling': '{$.meta.collection.duplicateHandling}',
#         'pdr': '{$.meta.pdr}',
#         'provider': '{$.meta.provider}',
#         'stack': '{$.meta.stack}'}}},
#      'Resource': 'arn:aws:lambda:us-west-2:xxxxxxxxxxxx:function:sharedsbx-SyncGranule',
#      'Retry': [{'ErrorEquals': ['States.ALL'],
#        'IntervalSeconds': 2,
#        'MaxAttempts': 3}],
#      'Type': 'Task'},
#     'UpdateMetadataLinks': {'Catch': [{'ErrorEquals': ['States.ALL'],
#        'Next': 'WorkflowFailed',
#        'ResultPath': '$.exception'}],
#      'Next': 'ChooseHyraxOrDone',
#      'Parameters': {'cma': {'event.$': '$',
#        'task_config': {'bucket': '{$.payload.system_bucket}',
#         'buckets': '{$.meta.buckets}',
#         'collection': '{$.meta.collection}',
#         'cumulus_message': {'outputs': [{'destination': '{$.payload}',
#            'source': '{$}'}]},
#         'distribution_endpoint': '{$.meta.distribution_endpoint}',
#         'duplicateHandling': '{$.meta.collection.duplicateHandling}'}}},
#      'Resource': 'arn:aws:lambda:us-west-2:xxxxxxxxxxxx:function:sharedsbx-UpdateGranulesCmrMetadataFileLinks',
#      'Retry': [{'BackoffRate': 2,
#        'ErrorEquals': ['Lambda.ServiceException',
#         'Lambda.AWSLambdaException',
#         'Lambda.SdkClientException'],
#        'IntervalSeconds': 2,
#        'MaxAttempts': 6}],
#      'Type': 'Task'},
#     'WorkflowFailed': {'Cause': 'Workflow failed', 'Type': 'Fail'},
#     'WorkflowSucceeded': {'Type': 'Succeed'}}},
#   'name': 'IngestGranule'}]

# %%
cml.get_workflow(workflow_name="HelloWorldWorkflow")
# Out:
# {'arn': 'arn:aws:states:us-west-2:xxxxxxxxxxxx:stateMachine:sharedsbx-HelloWorldWorkflow',
#  'definition': {'Comment': 'Returns Hello World',
#   'StartAt': 'HelloWorld',
#   'States': {'HelloWorld': {'End': True,
#     'Parameters': {'cma': {'event.$': '$',
#       'task_config': {'buckets': '{$.meta.buckets}',
#        'collection': '{$.meta.collection}',
#        'provider': '{$.meta.provider}'}}},
#     'Resource': 'arn:aws:lambda:us-west-2:xxxxxxxxxxxx:function:sharedsbx-HelloWorld',
#     'Retry': [{'BackoffRate': 2,
#       'ErrorEquals': ['Lambda.ServiceException',
#        'Lambda.AWSLambdaException',
#        'Lambda.SdkClientException'],
#       'IntervalSeconds': 2,
#       'MaxAttempts': 6}],
#     'Type': 'Task'}}},
#  'name': 'HelloWorldWorkflow'}
