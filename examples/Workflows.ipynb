# %%
from cumulus_api import CumulusApi
cml = CumulusApi()

# %%
cml.list_workflows()
# Out:
# [{'arn': 'arn:aws:states:us-west-2:xxxxxxxxxx:stateMachine:ghrcwuat-DiscoverGranules',
#   'definition': {'Comment': 'Discovers new Granules from a given provider',
#    'StartAt': 'DynamicDiscoverGranules',
#    'States': {'DiscoverGranules': {'Catch': [{'ErrorEquals': ['States.ALL'],
#        'Next': 'WorkflowFailed',
#        'ResultPath': '$.exception'}],
#      'Next': 'QueueGranules',
#      'Parameters': {'cma': {'ReplaceConfig': {'FullMessage': True},
#        'event.$': '$',
#        'task_config': {'buckets': '{$.meta.buckets}',
#         'collection': '{$.meta.collection}',
#         'provider': '{$.meta.provider}',
#         'stack': '{$.meta.stack}'}}},
#      'Resource': 'arn:aws:lambda:us-west-2:xxxxxxxxxx:function:ghrcwuat-DiscoverGranules',
#      'Retry': [{'BackoffRate': 2,
#        'ErrorEquals': ['Lambda.ServiceException',
#         'Lambda.AWSLambdaException',
#         'Lambda.SdkClientException'],
#        'IntervalSeconds': 2,
#        'MaxAttempts': 6}],
# ...

# %%
cml.get_workflow("HelloWorldWorkflow")
# Out:
# {'arn': 'arn:aws:states:us-west-2:xxxxxxxxxx:stateMachine:ghrcwuat-HelloWorldWorkflow',
#  'definition': {'Comment': 'Returns Hello World',
#   'StartAt': 'HelloWorld',
#   'States': {'HelloWorld': {'End': True,
#     'Parameters': {'cma': {'event.$': '$',
#       'task_config': {'buckets': '{$.meta.buckets}',
#        'collection': '{$.meta.collection}',
#        'provider': '{$.meta.provider}'}}},
#     'Resource': 'arn:aws:lambda:us-west-2:xxxxxxxxxx:function:ghrcwuat-HelloWorld',
#     'Retry': [{'BackoffRate': 2,
#       'ErrorEquals': ['Lambda.ServiceException',
#        'Lambda.AWSLambdaException',
#        'Lambda.SdkClientException'],
#       'IntervalSeconds': 2,
#       'MaxAttempts': 6}],
#     'Type': 'Task'}}},
#  'name': 'HelloWorldWorkflow'}
